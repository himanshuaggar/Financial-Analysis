# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
mzdock_stock = yf.download("MAZDOCK.NS", start="2019-06-04", end="2024-06-04")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
mzdock_stock
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-10-12   214.899994   216.949997   171.949997   171.949997   158.279800
# 2020-10-13   172.000000   184.699997   164.000000   181.449997   167.024551
# 2020-10-14   180.449997   187.399994   178.100006   182.250000   167.760941
# 2020-10-15   181.949997   182.750000   171.000000   171.850006   158.187790
# 2020-10-16   173.750000   175.449997   165.000000   168.050003   154.689880
# ...                 ...          ...          ...          ...          ...
# 2024-05-28  3155.000000  3170.699951  3005.800049  3036.850098  3036.850098
# 2024-05-29  3014.899902  3403.949951  2975.000000  3357.350098  3357.350098
# 2024-05-30  3370.000000  3478.000000  3260.399902  3295.100098  3295.100098
# 2024-05-31  3308.000000  3333.899902  3142.000000  3184.050049  3184.050049
# 2024-06-03  3439.699951  3439.699951  3230.000000  3257.600098  3257.600098
#
#               Volume
# Date
# ...

# %%
irfc_stock = yf.download("IRFC.NS", start="2019-06-04", end="2024-06-04")
hal_stock = yf.download("HAL.NS", start="2019-06-04", end="2024-06-04")
bdl_stock = yf.download("BDL.NS", start="2019-06-04", end="2024-06-04")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
mzdock_stock["Daily_Return"] = mzdock_stock["Adj Close"].pct_change()
irfc_stock["Daily_Return"] = irfc_stock["Adj Close"].pct_change()
hal_stock["Daily_Return"] = hal_stock["Adj Close"].pct_change()
bdl_stock["Daily_Return"] = bdl_stock["Adj Close"].pct_change()

# %%
mzdock_stock.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-10-12  214.899994  216.949997  171.949997  171.949997  158.279800
# 2020-10-13  172.000000  184.699997  164.000000  181.449997  167.024551
# 2020-10-14  180.449997  187.399994  178.100006  182.250000  167.760941
# 2020-10-15  181.949997  182.750000  171.000000  171.850006  158.187790
# 2020-10-16  173.750000  175.449997  165.000000  168.050003  154.689880
#
#               Volume  Daily_Return
# Date
# 2020-10-12  39928977           NaN
# 2020-10-13  18857924      0.055249
# 2020-10-14   6177891      0.004409
# 2020-10-15   3193458     -0.057064
# 2020-10-16   3072442     -0.022112

# %%
irfc_stock.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2021-01-29  24.900000  25.799999  24.350000  24.799999  21.363665  381938573
# 2021-02-01  25.250000  25.400000  24.900000  25.100000  21.622099   72044464
# 2021-02-02  25.450001  25.450001  24.700001  24.750000  21.320591   36735442
# 2021-02-03  24.799999  24.900000  24.049999  24.250000  20.889877   45816269
# 2021-02-04  24.250000  25.799999  23.850000  25.350000  21.837456   88486029
#
#             Daily_Return
# Date
# 2021-01-29           NaN
# 2021-02-01      0.012097
# 2021-02-02     -0.013944
# 2021-02-03     -0.020202
# 2021-02-04      0.045361

# %%
hal_stock.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-06-04  366.000000  369.950012  361.000000  362.075012  311.266632
# 2019-06-06  363.500000  365.000000  352.649994  355.325012  305.463776
# 2019-06-07  360.024994  361.000000  353.750000  356.825012  306.753296
# 2019-06-10  357.549988  359.524994  346.575012  350.575012  301.380402
# 2019-06-11  350.524994  356.899994  345.000000  352.850006  303.336121
#
#             Volume  Daily_Return
# Date
# 2019-06-04   27560           NaN
# 2019-06-06   20470     -0.018643
# 2019-06-07   15728      0.004222
# 2019-06-10   15070     -0.017515
# 2019-06-11   18060      0.006489

# %%
bdl_stock.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-06-04  152.350006  153.375000  148.125000  151.925003  138.902084
# 2019-06-06  151.949997  151.949997  145.500000  146.500000  133.942093
# 2019-06-07  144.324997  147.375000  144.324997  145.324997  132.867828
# 2019-06-10  145.024994  146.500000  142.050003  142.750000  130.513565
# 2019-06-11  142.000000  151.649994  140.750000  146.074997  133.553528
#
#             Volume  Daily_Return
# Date
# 2019-06-04   65570           NaN
# 2019-06-06   44280     -0.035709
# 2019-06-07   27626     -0.008020
# 2019-06-10   39814     -0.017719
# 2019-06-11  215800      0.023292

# %%
plt.plot(mzdock_stock["Daily_Return"])
plt.title("MazgonDock Daily Return")
plt.xlabel("Date")
plt.ylabel("Daily Return")
plt.show()

# %%
plt.plot(irfc_stock["Daily_Return"])
plt.title("MazgonDock Daily Return")
plt.xlabel("Date")
plt.ylabel("Daily Return")
plt.show()

# %%
plt.plot(hal_stock["Daily_Return"])
plt.title("MazgonDock Daily Return")
plt.xlabel("Date")
plt.ylabel("Daily Return")
plt.show()

# %%
plt.plot(bdl_stock["Daily_Return"])
plt.title("MazgonDock Daily Return")
plt.xlabel("Date")
plt.ylabel("Daily Return")
plt.show()

# %% [markdown]
# <p id = 'mas' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; color: #333; text-align: justify;"><b>Moving Averages</b></p>
# <br>
#
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">Moving averages are commonly used to smooth out price fluctuations and identify trends in the price action of stocks, commodities, forex, crypto, and many others.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">A moving average is calculated by taking the average price of an asset over a certain period of time. This period can be as nine days or as long as 200 days, depending on the trader's preference and the asset being analyzed. The resulting line that represents the moving average is then plotted on a chart, and traders use this line to gauge the direction and strength of the trend.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">There are two types of moving averages: simple moving averages (SMA) and exponential moving averages (EMA). SMA calculates the average price of the asset over the specified period of time and gives equal weight to each data point.So, for instance, a 20-day SMA would take the sum of the closing prices over the past 20 days and divide by 20 to get the average price.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18p3; text-align: justify;">EMA, on the other hand, gives more weight to recent price action. The formula for calculating EMA involves using a multiplier that gives more weight to the most recent price data. The formula for calculating a 9-day EMA, for example, would be:
# </p>
# <br><br>
# <p id="prior" style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: center;">
#     $EMA = (\text{Close - EMA(previous day))} \times {Multiplier} + \text{EMA(previous day)}$
# </p>
# <br><br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">The multiplier used depends on the length of the period used. For a 9-day EMA, the multiplier would be 2/(9+1) = 0.2 (rounded to one decimal place).</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">Traders often use moving averages to identify dynamic support and resistance levels, as well as to spot potential trend changes. When the price of an asset is above its moving average, it is considered to be in an uptrend, while a price below the moving average is considered to be in a downtrend. Traders also look for crossovers between different moving averages, which can signal a change in trend direction, such as the Golden Cross (when the 50-day moving average crosses above the 200-day moving average) and Death Cross (when the 50-day moving average crosse below the 200-day moving average).</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">Moving averages can also be used to set stop loss and take profit levels for trades. For example, a trader may place a stop loss order below the moving average to limit their losses if the trend reverses.</p>
# <br>
# <br>

# %%
mzdock_stock["50_MA"] = mzdock_stock["Adj Close"].rolling(window =50).mean()
mzdock_stock["150_MA"] = mzdock_stock["Adj Close"].rolling(window =150).mean()
mzdock_stock["365_MA"] = mzdock_stock["Adj Close"].rolling(window =365).mean()

# %%
mzdock_stock.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-05-28  3155.000000  3170.699951  3005.800049  3036.850098  3036.850098
# 2024-05-29  3014.899902  3403.949951  2975.000000  3357.350098  3357.350098
# 2024-05-30  3370.000000  3478.000000  3260.399902  3295.100098  3295.100098
# 2024-05-31  3308.000000  3333.899902  3142.000000  3184.050049  3184.050049
# 2024-06-03  3439.699951  3439.699951  3230.000000  3257.600098  3257.600098
#
#              Volume  Daily_Return        50_MA       150_MA       365_MA
# Date
# 2024-05-28  2367178     -0.031200  2266.994004  2166.386903  1572.761972
# 2024-05-29  9455928      0.105537  2293.777007  2174.535012  1579.489035
# 2024-05-30  6099790     -0.018541  2322.500010  2182.194036  1586.039859
# 2024-05-31  3812467     -0.033702  2348.314011  2189.174242  1592.292263
# 2024-06-03  2596648      0.023100  2375.122014  2196.727467  1598.806875

# %%
mzdock_stock
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-10-12   214.899994   216.949997   171.949997   171.949997   158.279800
# 2020-10-13   172.000000   184.699997   164.000000   181.449997   167.024551
# 2020-10-14   180.449997   187.399994   178.100006   182.250000   167.760941
# 2020-10-15   181.949997   182.750000   171.000000   171.850006   158.187790
# 2020-10-16   173.750000   175.449997   165.000000   168.050003   154.689880
# ...                 ...          ...          ...          ...          ...
# 2024-05-28  3155.000000  3170.699951  3005.800049  3036.850098  3036.850098
# 2024-05-29  3014.899902  3403.949951  2975.000000  3357.350098  3357.350098
# 2024-05-30  3370.000000  3478.000000  3260.399902  3295.100098  3295.100098
# 2024-05-31  3308.000000  3333.899902  3142.000000  3184.050049  3184.050049
# 2024-06-03  3439.699951  3439.699951  3230.000000  3257.600098  3257.600098
#
# ...

# %%
irfc_stock["50_MA"] =irfc_stock["Adj Close"].rolling(window =50).mean()
irfc_stock["150_MA"] =irfc_stock["Adj Close"].rolling(window =150).mean()
irfc_stock["365_MA"] =irfc_stock["Adj Close"].rolling(window =365).mean()

# %%
hal_stock["50_MA"] = hal_stock["Adj Close"].rolling(window =50).mean()
hal_stock["150_MA"] = hal_stock["Adj Close"].rolling(window =150).mean()
hal_stock["365_MA"] = hal_stock["Adj Close"].rolling(window =365).mean()

# %%
bdl_stock["50_MA"] = bdl_stock["Adj Close"].rolling(window =50).mean()
bdl_stock["150_MA"] = bdl_stock["Adj Close"].rolling(window =150).mean()
bdl_stock["365_MA"] = bdl_stock["Adj Close"].rolling(window =365).mean()

# %%
irfc_stock
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-29   24.900000   25.799999   24.350000   24.799999   21.363665
# 2021-02-01   25.250000   25.400000   24.900000   25.100000   21.622099
# 2021-02-02   25.450001   25.450001   24.700001   24.750000   21.320591
# 2021-02-03   24.799999   24.900000   24.049999   24.250000   20.889877
# 2021-02-04   24.250000   25.799999   23.850000   25.350000   21.837456
# ...                ...         ...         ...         ...         ...
# 2024-05-28  186.000000  187.750000  177.500000  180.250000  180.250000
# 2024-05-29  178.500000  181.750000  175.300003  180.300003  180.300003
# 2024-05-30  180.300003  182.100006  175.800003  176.600006  176.600006
# 2024-05-31  179.000000  179.850006  172.100006  177.800003  177.800003
# 2024-06-03  200.000000  200.000000  186.300003  188.949997  188.949997
#
#                Volume  Daily_Return    50_MA      150_MA     365_MA
# Date
# ...

# %%
hal_stock
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-06-04   366.000000   369.950012   361.000000   362.075012   311.266632
# 2019-06-06   363.500000   365.000000   352.649994   355.325012   305.463776
# 2019-06-07   360.024994   361.000000   353.750000   356.825012   306.753296
# 2019-06-10   357.549988   359.524994   346.575012   350.575012   301.380402
# 2019-06-11   350.524994   356.899994   345.000000   352.850006   303.336121
# ...                 ...          ...          ...          ...          ...
# 2024-05-28  5139.000000  5207.899902  4955.000000  5019.750000  5019.750000
# 2024-05-29  5000.000000  5152.000000  4950.000000  5051.750000  5051.750000
# 2024-05-30  5062.049805  5090.000000  4953.049805  4976.250000  4976.250000
# 2024-05-31  5020.000000  5042.799805  4862.200195  4973.850098  4973.850098
# 2024-06-03  5444.000000  5444.000000  5162.299805  5273.649902  5273.649902
#
# ...

# %%
bdl_stock
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-06-04   152.350006   153.375000   148.125000   151.925003   138.902084
# 2019-06-06   151.949997   151.949997   145.500000   146.500000   133.942093
# 2019-06-07   144.324997   147.375000   144.324997   145.324997   132.867828
# 2019-06-10   145.024994   146.500000   142.050003   142.750000   130.513565
# 2019-06-11   142.000000   151.649994   140.750000   146.074997   133.553528
# ...                 ...          ...          ...          ...          ...
# 2024-05-28  1542.000000  1542.000000  1431.250000  1453.449951  1453.449951
# 2024-05-29  1444.000000  1554.000000  1411.000000  1540.800049  1540.800049
# 2024-05-30  1555.000000  1598.000000  1525.000000  1547.550049  1547.550049
# 2024-05-31  1626.000000  1630.000000  1486.050049  1557.349976  1557.349976
# 2024-06-03  1662.949951  1662.949951  1580.099976  1596.500000  1596.500000
#
# ...

# %%
plt.plot(mzdock_stock["Adj Close"], label="Adj Close")
plt.plot(mzdock_stock["50_MA"], label="50-day MA")
plt.plot(mzdock_stock["150_MA"], label="150-day MA")
plt.plot(mzdock_stock["365_MA"], label="365-day MA")
plt.title("Mazagondock stock price & 50D MA & 150D MA & 365D MA")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.plot(irfc_stock["Adj Close"], label="Adj Close")
plt.plot(irfc_stock["50_MA"], label="50-day MA")
plt.plot(irfc_stock["150_MA"], label="150-day MA")
plt.plot(irfc_stock["365_MA"], label="365-day MA")
plt.title("Mazagondock stock price & 50D MA & 150D MA & 365D MA")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.plot(hal_stock["Adj Close"], label="Adj Close")
plt.plot(hal_stock["50_MA"], label="50-day MA")
plt.plot(hal_stock["150_MA"], label="150-day MA")
plt.plot(hal_stock["365_MA"], label="365-day MA")
plt.title("Mazagondock stock price & 50D MA & 150D MA & 365D MA")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.plot(bdl_stock["Adj Close"], label="Adj Close")
plt.plot(bdl_stock["50_MA"], label="50-day MA")
plt.plot(bdl_stock["150_MA"], label="150-day MA")
plt.plot(bdl_stock["365_MA"], label="365-day MA")
plt.title("Mazagondock stock price & 50D MA & 150D MA & 365D MA")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
volt_mz = mzdock_stock["Daily_Return"].std()
print(f"Volatitlity : { volt_mz}")
# Out:
# Volatitlity : 0.03136717219339633

# %%
volt_irfc = irfc_stock["Daily_Return"].std()
print(f"Volatitlity : { volt_irfc}")
# Out:
# Volatitlity : 0.02685772226692845

# %%
volt_hal = hal_stock["Daily_Return"].std()
print(f"Volatitlity : { volt_hal}")
# Out:
# Volatitlity : 0.023296434426300163

# %%
volt_bdl = bdl_stock["Daily_Return"].std()
print(f"Volatitlity : { volt_bdl}")
# Out:
# Volatitlity : 0.029518120356030943

# %% [markdown]
# <h2 id= 'sharpe-ratio' style="font-family: 'Cambria', Georgia, serif; font-weight: bold; margin-bottom: 20px; text-align: left; letter-spacing: 1px;">Sharpe Ratio</h2>

# %% [markdown]
# <p style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px;  text-align: justify;">The Sharpe ratio is a measure of the risk-adjusted return of an investment. It is calculated by dividing the average excess return of the investment over the standard deviation of the returns, as shown by the following equation:</p>
# <br><br>
# <div style="display: flex; justify-content: center;">
#   <center><img src="https://latex.codecogs.com/png.image?\dpi{150}&space;\bg_white&space;\text{Sharpe&space;ratio}&space;=&space;\frac{R_p&space;-&space;R_f}{\sigma_p}" title="\text{Sharpe ratio} = \frac{R_p - R_f}{\sigma_p}" /></center>
# </div>
# <br><br>
# <p style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">where <b><i>R<sub>p</sub></i></b> is the average return of the investment, <i><b>R<sub>f</sub></b></i> is the risk-free rate of return, and <i><b>σ<sub>p</sub></b></i> is the standard deviation of the returns. The average excess return is the difference between the average return of the investment and the risk-free rate of return, typically represented by a government bond. The standard deviation is a measurement of the volatility of returns.</p>
# <br>
# <p style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">A higher Sharpe ratio indicates that an investment provides higher returns for a given level of risk compared to other investments with a lower Sharpe ratio. In general, a Sharpe ratio greater than 1 is considered good, while a Sharpe ratio less than 1 is considered poor. A Sharpe ratio of 1 means that the investment's average return is equal to the risk-free rate of return.</p>
# <br>
# <p style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px;  text-align: justify;">In general, a Sharpe ratio under 1.0 is considered bad, equal to 1.0 is considered acceptable or good, 2.0 or higher is rated as very good, and 3.0 or higher is considered excellent.</p>

# %%
ris_free_rate = 0.01
annual_return_mz= (mzdock_stock["Daily_Return"].mean()+1) ** 252-1
annual_vol_mz = mzdock_stock["Daily_Return"].std() * np.sqrt(252)
sharpe_ratio_mz = (annual_return_mz - ris_free_rate)/ annual_vol_mz
print(f"Sharpe Ratio : { sharpe_ratio_mz}")
# Out:
# Sharpe Ratio : 3.257441932724761

# %%
ris_free_rate = 0.01
annual_return_irfc= (irfc_stock["Daily_Return"].mean()+1) ** 252-1
annual_vol_irfc = irfc_stock["Daily_Return"].std() * np.sqrt(252)
sharpe_ratio_irfc = (annual_return_irfc - ris_free_rate)/ annual_vol_irfc
print(f"Sharpe Ratio : { sharpe_ratio_irfc}")
# Out:
# Sharpe Ratio : 2.61994785461367

# %%
ris_free_rate = 0.01
annual_return_hal= (hal_stock["Daily_Return"].mean()+1) ** 252-1
annual_vol_hal = hal_stock["Daily_Return"].std() * np.sqrt(252)
sharpe_ratio_hal = (annual_return_hal - ris_free_rate)/ annual_vol_hal
print(f"Sharpe Ratio : { sharpe_ratio_hal}")
# Out:
# Sharpe Ratio : 2.4234535807274042

# %%
ris_free_rate = 0.01
annual_return_bdl= (bdl_stock["Daily_Return"].mean()+1) ** 252-1
annual_vol_bdl = bdl_stock["Daily_Return"].std() * np.sqrt(252)
sharpe_ratio_bdl = (annual_return_bdl - ris_free_rate)/ annual_vol_bdl
print(f"Sharpe Ratio : { sharpe_ratio_bdl}")
# Out:
# Sharpe Ratio : 1.7583642196102287

# %%
sensex = yf.download("^BSESN", start="2019-06-04", end="2024-06-04")
nifty50 = yf.download("^NSEI", start="2019-06-04", end="2024-06-04")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
sensex
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-06-04  40196.000000  40312.070312  40031.050781  40083.539062
# 2019-06-06  40136.429688  40159.261719  39481.148438  39529.718750
# 2019-06-07  39581.769531  39703.101562  39279.468750  39615.898438
# 2019-06-10  39787.328125  39979.480469  39619.968750  39784.519531
# 2019-06-11  39900.449219  40066.308594  39760.019531  39950.460938
# ...                  ...           ...           ...           ...
# 2024-05-28  75585.398438  75585.398438  75083.218750  75170.453125
# 2024-05-29  74826.937500  74986.218750  74454.546875  74502.898438
# 2024-05-30  74365.882812  74493.546875  73668.726562  73885.601562
# 2024-05-31  74208.531250  74478.890625  73765.148438  73961.312500
# 2024-06-03  76583.289062  76738.890625  75678.429688  76468.781250
#
#                Adj Close  Volume
# Date
# 2019-06-04  40083.539062   11900
# 2019-06-06  39529.718750   18700
# 2019-06-07  39615.898438   14800
# ...

# %%
nifty50
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-06-04  12052.650391  12095.200195  12005.849609  12021.650391
# 2019-06-06  12039.799805  12039.799805  11830.250000  11843.750000
# 2019-06-07  11865.200195  11897.500000  11769.500000  11870.650391
# 2019-06-10  11934.900391  11975.049805  11871.750000  11922.700195
# 2019-06-11  11959.849609  12000.349609  11904.349609  11965.599609
# ...                  ...           ...           ...           ...
# 2024-05-28  22977.150391  22998.550781  22858.500000  22888.150391
# 2024-05-29  22762.750000  22825.500000  22685.449219  22704.699219
# 2024-05-30  22617.449219  22705.750000  22417.000000  22488.650391
# 2024-05-31  22568.099609  22653.750000  22465.099609  22530.699219
# 2024-06-03  23337.900391  23338.699219  23062.300781  23263.900391
#
#                Adj Close  Volume
# Date
# 2019-06-04  12021.650391  289200
# 2019-06-06  11843.750000  415200
# 2019-06-07  11870.650391  302500
# ...

# %%
sensex["Daily_return_Sensex"] = sensex["Adj Close"].pct_change()
sensex
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-06-04  40196.000000  40312.070312  40031.050781  40083.539062
# 2019-06-06  40136.429688  40159.261719  39481.148438  39529.718750
# 2019-06-07  39581.769531  39703.101562  39279.468750  39615.898438
# 2019-06-10  39787.328125  39979.480469  39619.968750  39784.519531
# 2019-06-11  39900.449219  40066.308594  39760.019531  39950.460938
# ...                  ...           ...           ...           ...
# 2024-05-28  75585.398438  75585.398438  75083.218750  75170.453125
# 2024-05-29  74826.937500  74986.218750  74454.546875  74502.898438
# 2024-05-30  74365.882812  74493.546875  73668.726562  73885.601562
# 2024-05-31  74208.531250  74478.890625  73765.148438  73961.312500
# 2024-06-03  76583.289062  76738.890625  75678.429688  76468.781250
#
#                Adj Close  Volume  Daily_return_Sensex
# Date
# 2019-06-04  40083.539062   11900                  NaN
# ...

# %%
nifty50["Daily_return_Nifty"] = nifty50["Adj Close"].pct_change()
nifty50
# Out:
#                     Open          High           Low         Close  \
# Date
# 2019-06-04  12052.650391  12095.200195  12005.849609  12021.650391
# 2019-06-06  12039.799805  12039.799805  11830.250000  11843.750000
# 2019-06-07  11865.200195  11897.500000  11769.500000  11870.650391
# 2019-06-10  11934.900391  11975.049805  11871.750000  11922.700195
# 2019-06-11  11959.849609  12000.349609  11904.349609  11965.599609
# ...                  ...           ...           ...           ...
# 2024-05-28  22977.150391  22998.550781  22858.500000  22888.150391
# 2024-05-29  22762.750000  22825.500000  22685.449219  22704.699219
# 2024-05-30  22617.449219  22705.750000  22417.000000  22488.650391
# 2024-05-31  22568.099609  22653.750000  22465.099609  22530.699219
# 2024-06-03  23337.900391  23338.699219  23062.300781  23263.900391
#
#                Adj Close  Volume  \
# Date
# 2019-06-04  12021.650391  289200
# 2019-06-06  11843.750000  415200
# 2019-06-07  11870.650391  302500
# ...

# %%
joined_data = pd.concat([mzdock_stock["Daily_Return"],irfc_stock["Daily_Return"],hal_stock["Daily_Return"],bdl_stock["Daily_Return"], sensex["Daily_return_Sensex"], nifty50["Daily_return_Nifty"]], axis=1).dropna()

# %%
joined_data.head()
# Out:
#             Daily_Return  Daily_Return  Daily_Return  Daily_Return  \
# Date
# 2021-02-01      0.028219      0.012097     -0.017616      0.003777
# 2021-02-02     -0.005074     -0.013944      0.028328      0.003160
# 2021-02-03      0.001854     -0.020202      0.032041      0.002250
# 2021-02-04      0.015039      0.045361      0.012076      0.008681
# 2021-02-05     -0.001140      0.013807      0.037896      0.001929
#
#             Daily_return_Sensex  Daily_return_Nifty
# Date
# 2021-02-01             0.050012            0.047424
# 2021-02-02             0.024632            0.025674
# 2021-02-03             0.009198            0.009701
# 2021-02-04             0.007134            0.007147
# 2021-02-05             0.002318            0.001920

# %% [markdown]
# <h2 id='beta-alpha' style="font-family: 'Cambria', Georgia, serif; font-weight: bold; margin-bottom: 20px; text-align: left; letter-spacing: 1px;">Beta and Alpha</h2>

# %% [markdown]
# <p style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">Beta and Alpha are two key metrics used in finance to evaluate the performance of a stock relative to the overall market. Beta is a measure of a stock's volatility compared to the market. A Beta of 1 means that the stock is as volatile as the market, a Beta greater than 1 indicates higher volatility than the market, and a Beta less than 1 suggests lower volatility.</p>
# <br>
# <p style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">Alpha, on the other hand, is a measurement of a stock's excess return relative to its expected performance based on its Beta. A positive Alpha indicates that a stock has outperformed its expected performance based on its Beta, while a negative Alpha suggests underperformance. By analyzing the Beta and Alpha values of stocks, investors can get a better understanding of the risk and potential returns of the stock compared to the market, and make informed investment decisions accordingly.</p>
# <br>
# <p style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">To determine Beta and Alpha, we require data from the Nifty50 & Sensex, which acts as the benchmark, to fit a linear regression model between the stocks and the index. This will enable us to extract the Beta and Alpha values of the stocks.</p>

# %%
beta_mz_nifty = joined_data.cov().iloc[0,5]/ joined_data["Daily_return_Nifty"].var()
print(f"Beta: {beta_mz_nifty}")
# Out:
# Beta: 1.122508677470615

# %%
beta_irfc_nifty = joined_data.cov().iloc[1,5]/ joined_data["Daily_return_Nifty"].var()
print(f"Beta: {beta_irfc_nifty}")
# Out:
# Beta: 0.7521883683759062

# %%
beta_hal_nifty = joined_data.cov().iloc[2,5]/ joined_data["Daily_return_Nifty"].var()
print(f"Beta: {beta_hal_nifty}")
# Out:
# Beta: 0.8694117886066604

# %%
beta_bdl_nifty = joined_data.cov().iloc[3,5]/ joined_data["Daily_return_Nifty"].var()
print(f"Beta: {beta_bdl_nifty}")
# Out:
# Beta: 0.7755314022609904

# %%
beta_mz_sensex = joined_data.cov().iloc[0,4]/ joined_data["Daily_return_Sensex"].var()
print(f"Beta: {beta_mz_sensex}")
# Out:
# Beta: 1.0362539238661015

# %%
beta_irfc_sensex = joined_data.cov().iloc[1,4]/ joined_data["Daily_return_Sensex"].var()
print(f"Beta: {beta_irfc_sensex}")
# Out:
# Beta: 0.6979029412189408

# %%
beta_hal_sensex = joined_data.cov().iloc[2,4]/ joined_data["Daily_return_Sensex"].var()
print(f"Beta: {beta_hal_sensex}")
# Out:
# Beta: 0.8109146130313712

# %%
beta_bdl_sensex = joined_data.cov().iloc[3,4]/ joined_data["Daily_return_Sensex"].var()
print(f"Beta: {beta_bdl_sensex}")
# Out:
# Beta: 0.7104553462646069

# %% [markdown]
# <p id = 'bbs' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;"><b>Bollinger Bands</b></p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">Bollinger Bands are an exteremely popular tool used by traders and analysts to measure volatility and to identify potential buy and sell opportunities.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">The Bollinger Bands consist of three lines on a chart: a simple moving average (SMA) in the middle,typically a 20-day moving average, and two bands that are set at a distance of two standard deviations away from the SMA. When the market is volatile, the bands widen, and when the market is less volatile, the bands contract. The distance between the bands can therefore be used as an indicator of volatility.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">Usually, traders use these bands to identify possible buying and selling entries. When the price touches or crosses below the lower band, it may be considered oversold and a potential buy signal. Conversely, when the price touches or crosses above the upper band, it may be considered overbought and a potential sell signal.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">To obtain the Bollinger Bands values, there are three important steps:</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">1. Calculate the 20-day SMA of the stock's price.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">2. Calculate the standard deviation of the stocks's price over the past 20 periods.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">3.Calculate the upper and lower bands by adding or subtracting two standard deviations from the 20-day SMA.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">The formula to calculate the upper band is:</p>
# <br><br>
# <p id="prior" style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: center;">$Upper\ Band = 20\text{day}\ SMA + (2 \times \sigma)$
# </p>
# <br><br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">Whereas the formula for the lower band is:</p>
# <br><br>
# <p id="prior" style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: center;">
#     $Lower\ Band = 20\text{day}\ SMA - (2 \times \sigma)$
# </p>
# <br>
# <br>

# %%
#Bollinger Bands
mzdock_stock["20_MA"] = mzdock_stock["Adj Close"].rolling(window =20).mean()

# %%
mzdock_stock["Upper_Band"] = mzdock_stock["20_MA"] + 2* mzdock_stock["Adj Close"].rolling(window = 20).std()

# %%
mzdock_stock.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-05-28  3155.000000  3170.699951  3005.800049  3036.850098  3036.850098
# 2024-05-29  3014.899902  3403.949951  2975.000000  3357.350098  3357.350098
# 2024-05-30  3370.000000  3478.000000  3260.399902  3295.100098  3295.100098
# 2024-05-31  3308.000000  3333.899902  3142.000000  3184.050049  3184.050049
# 2024-06-03  3439.699951  3439.699951  3230.000000  3257.600098  3257.600098
#
#              Volume  Daily_Return        50_MA       150_MA       365_MA  \
# Date
# 2024-05-28  2367178     -0.031200  2266.994004  2166.386903  1572.761972
# 2024-05-29  9455928      0.105537  2293.777007  2174.535012  1579.489035
# 2024-05-30  6099790     -0.018541  2322.500010  2182.194036  1586.039859
# 2024-05-31  3812467     -0.033702  2348.314011  2189.174242  1592.292263
# 2024-06-03  2596648      0.023100  2375.122014  2196.727467  1598.806875
#
#                   20_MA   Upper_Band
# Date
# ...

# %%
mzdock_stock["Lower_Band"] = mzdock_stock["20_MA"] - 2* mzdock_stock["Adj Close"].rolling(window =20).std()

# %%
mzdock_stock.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-05-28  3155.000000  3170.699951  3005.800049  3036.850098  3036.850098
# 2024-05-29  3014.899902  3403.949951  2975.000000  3357.350098  3357.350098
# 2024-05-30  3370.000000  3478.000000  3260.399902  3295.100098  3295.100098
# 2024-05-31  3308.000000  3333.899902  3142.000000  3184.050049  3184.050049
# 2024-06-03  3439.699951  3439.699951  3230.000000  3257.600098  3257.600098
#
#              Volume  Daily_Return        50_MA       150_MA       365_MA  \
# Date
# 2024-05-28  2367178     -0.031200  2266.994004  2166.386903  1572.761972
# 2024-05-29  9455928      0.105537  2293.777007  2174.535012  1579.489035
# 2024-05-30  6099790     -0.018541  2322.500010  2182.194036  1586.039859
# 2024-05-31  3812467     -0.033702  2348.314011  2189.174242  1592.292263
# 2024-06-03  2596648      0.023100  2375.122014  2196.727467  1598.806875
#
#                   20_MA   Upper_Band   Lower_Band
# ...

# %%
plt.plot(mzdock_stock["Adj Close"], label="Adj Close")
plt.plot(mzdock_stock["20_MA"], label="20 Day MA")
plt.plot(mzdock_stock["Upper_Band"], label="Upper Band")
plt.plot(mzdock_stock["Lower_Band"], label="Lower Band")
plt.title("Mazagondock Stock Price and Bollinger Bands")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
irfc_stock["20_MA"] = irfc_stock["Adj Close"].rolling(window =20).mean()
irfc_stock["Upper_Band"] = irfc_stock["20_MA"] + 2* irfc_stock["Adj Close"].rolling(window = 20).std()
irfc_stock["Lower_Band"] = irfc_stock["20_MA"] - 2* irfc_stock["Adj Close"].rolling(window =20).std()

# %%
irfc_stock.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-05-28  186.000000  187.750000  177.500000  180.250000  180.250000
# 2024-05-29  178.500000  181.750000  175.300003  180.300003  180.300003
# 2024-05-30  180.300003  182.100006  175.800003  176.600006  176.600006
# 2024-05-31  179.000000  179.850006  172.100006  177.800003  177.800003
# 2024-06-03  200.000000  200.000000  186.300003  188.949997  188.949997
#
#                Volume  Daily_Return    50_MA      150_MA     365_MA  \
# Date
# 2024-05-28   79904182     -0.023300  150.795  123.778976  73.293124
# 2024-05-29   54953818      0.000277  151.666  124.475786  73.695202
# 2024-05-30   43583688     -0.020521  152.713  125.149907  74.086336
# 2024-05-31   56435354      0.006795  153.464  125.813233  74.483042
# 2024-06-03  112293004      0.062711  154.504  126.561773  74.912042
#
#                  20_MA  Upper_Band  Lower_Band
# Date
# 2024-05-28  163.127499  190.442628  135.812369
# ...

# %%
plt.plot(irfc_stock["Adj Close"], label="Adj Close")
plt.plot(irfc_stock["20_MA"], label="20 Day MA")
plt.plot(irfc_stock["Upper_Band"], label="Upper Band")
plt.plot(irfc_stock["Lower_Band"], label="Lower Band")
plt.title("IRFC Stock Price and Bollinger Bands")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
hal_stock["20_MA"] = hal_stock["Adj Close"].rolling(window =20).mean()
hal_stock["Upper_Band"] = hal_stock["20_MA"] + 2* hal_stock["Adj Close"].rolling(window = 20).std()
hal_stock["Lower_Band"] = hal_stock["20_MA"] - 2* hal_stock["Adj Close"].rolling(window =20).std()

# %%
hal_stock.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-05-28  5139.000000  5207.899902  4955.000000  5019.750000  5019.750000
# 2024-05-29  5000.000000  5152.000000  4950.000000  5051.750000  5051.750000
# 2024-05-30  5062.049805  5090.000000  4953.049805  4976.250000  4976.250000
# 2024-05-31  5020.000000  5042.799805  4862.200195  4973.850098  4973.850098
# 2024-06-03  5444.000000  5444.000000  5162.299805  5273.649902  5273.649902
#
#              Volume  Daily_Return        50_MA       150_MA       365_MA  \
# Date
# 2024-05-28  4402348     -0.023841  3808.708003  3016.782485  2163.587826
# 2024-05-29  4225666      0.006375  3844.392002  3037.389351  2173.721815
# 2024-05-30  2751972     -0.014945  3883.127002  3057.570976  2183.623599
# 2024-05-31  3912234     -0.000482  3919.285005  3077.733955  2193.506634
# 2024-06-03  4619434      0.060275  3962.776001  3099.902549  2204.244398
#
#                   20_MA   Upper_Band   Lower_Band
# ...

# %%
plt.plot(hal_stock["Adj Close"], label="Adj Close")
plt.plot(hal_stock["20_MA"], label="20 Day MA")
plt.plot(hal_stock["Upper_Band"], label="Upper Band")
plt.plot(hal_stock["Lower_Band"], label="Lower Band")
plt.title("HAL Stock Price and Bollinger Bands")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
bdl_stock["20_MA"] = bdl_stock["Adj Close"].rolling(window =20).mean()
bdl_stock["Upper_Band"] = bdl_stock["20_MA"] + 2* bdl_stock["Adj Close"].rolling(window = 20).std()
bdl_stock["Lower_Band"] = bdl_stock["20_MA"] - 2* bdl_stock["Adj Close"].rolling(window =20).std()

# %%
bdl_stock.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-05-28  1542.000000  1542.000000  1431.250000  1453.449951  1453.449951
# 2024-05-29  1444.000000  1554.000000  1411.000000  1540.800049  1540.800049
# 2024-05-30  1555.000000  1598.000000  1525.000000  1547.550049  1547.550049
# 2024-05-31  1626.000000  1630.000000  1486.050049  1557.349976  1557.349976
# 2024-06-03  1662.949951  1662.949951  1580.099976  1596.500000  1596.500000
#
#              Volume  Daily_Return        50_MA      150_MA      365_MA  \
# Date
# 2024-05-28  4259515     -0.059164   974.694611  809.788112  632.118317
# 2024-05-29  5436219      0.060098   988.321299  816.738765  635.038804
# 2024-05-30  4844466      0.004381  1003.450133  823.733092  637.975357
# 2024-05-31  7314397      0.006333  1018.099353  830.750299  640.944559
# 2024-06-03  3797720      0.025139  1033.294263  838.039948  644.024392
#
#                   20_MA   Upper_Band  Lower_Band
# Date
# ...

# %%
plt.plot(bdl_stock["Adj Close"], label="Adj Close")
plt.plot(bdl_stock["20_MA"], label="20 Day MA")
plt.plot(bdl_stock["Upper_Band"], label="Upper Band")
plt.plot(bdl_stock["Lower_Band"], label="Lower Band")
plt.title("BDL Stock Price and Bollinger Bands")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.show()

# %% [markdown]
# <p id = 'rsi' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;"><b>Relative Strenght Index (RSI)</b></p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">The RSI is another popular technical analysis tool used by traders and analysts in financial markets. It measures the strength of price action and can be used to identify possible buy and sell opportunities.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">The RSI is calculated by comparing the average gains and losses of a stock over a specific period of time. The formula for calculating the RSI involves two steps:</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">First, you calculate the Relative Strength (RS) of the stock, which is the ratio of the average gains to the average losses over time, which is typically the last 14 days.</p>
# <br><br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;"><center>$\text{RS} = \frac{Average\; Gain}{Average\; Loss}$</center></p>
# <br><br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">In order to obtain the average gain or loss, the difference between the closing price of the current day and the previous day is taken. If that difference is positive, then it is considered a gain, but if that difference is negative, it is considered a loss.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">The next step is to obtain the RSI using the RS value. The RSI ranges from 0 to 100 and is plotted on a chart.</p>
# <br><br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;"><center>$\text{RSI} = 100 - \frac{100}{1 + \text{RS}}$</center></p>
# <br><br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">When the RSI is above 70, it is considered an overbought region and could signal a potential opportunity for selling. When it is below the value of 30, it is considered to be on an oversold region and could signal a potential opportunity for buying low.</p>
# <br>
# <p id = 'prior' style="font-family: Georgia, 'Times New Roman', serif; font-size: 18px; text-align: justify;">The RSI is also popularly used to identify divergences between the RSI and price, which can indicate the loss of <i>momentum</i>, i.e. strenght, in the current trend and suggest a possible reversal.</p>
# <br>
# <br>

# %%
#Relative Strength Index
delta_mz = mzdock_stock["Adj Close"].diff(1)
gain_mz = (delta_mz.where(delta_mz>0,0)).rolling(window =14).mean()
loss_mz = (-delta_mz.where(delta_mz<0,0)).rolling(window =14).mean()

# %%
rs_mz = gain_mz/ loss_mz

# %%
mzdock_stock["RSI"] = 100 -(100/(1+rs_mz))

# %%
mzdock_stock.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2024-05-28  3155.000000  3170.699951  3005.800049  3036.850098  3036.850098
# 2024-05-29  3014.899902  3403.949951  2975.000000  3357.350098  3357.350098
# 2024-05-30  3370.000000  3478.000000  3260.399902  3295.100098  3295.100098
# 2024-05-31  3308.000000  3333.899902  3142.000000  3184.050049  3184.050049
# 2024-06-03  3439.699951  3439.699951  3230.000000  3257.600098  3257.600098
#
#              Volume  Daily_Return        50_MA       150_MA       365_MA  \
# Date
# 2024-05-28  2367178     -0.031200  2266.994004  2166.386903  1572.761972
# 2024-05-29  9455928      0.105537  2293.777007  2174.535012  1579.489035
# 2024-05-30  6099790     -0.018541  2322.500010  2182.194036  1586.039859
# 2024-05-31  3812467     -0.033702  2348.314011  2189.174242  1592.292263
# 2024-06-03  2596648      0.023100  2375.122014  2196.727467  1598.806875
#
# ...

# %%
plt.plot(mzdock_stock["RSI"])
plt.title("MazagonDock stock Relative Strength Index(RSI)")
plt.xlabel("Date")
plt.ylabel("RSI")
plt.show()

# %%
delta_irfc = irfc_stock["Adj Close"].diff(1)
gain_irfc = (delta_irfc.where(delta_irfc>0,0)).rolling(window =14).mean()
loss_irfc = (-delta_irfc.where(delta_irfc<0,0)).rolling(window =14).mean()
rs_irfc = gain_irfc/ loss_irfc
irfc_stock["RSI"] = 100 -(100/(1+rs_irfc))

# %%
irfc_stock.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-05-28  186.000000  187.750000  177.500000  180.250000  180.250000
# 2024-05-29  178.500000  181.750000  175.300003  180.300003  180.300003
# 2024-05-30  180.300003  182.100006  175.800003  176.600006  176.600006
# 2024-05-31  179.000000  179.850006  172.100006  177.800003  177.800003
# 2024-06-03  200.000000  200.000000  186.300003  188.949997  188.949997
#
#                Volume  Daily_Return    50_MA      150_MA     365_MA  \
# Date
# 2024-05-28   79904182     -0.023300  150.795  123.778976  73.293124
# 2024-05-29   54953818      0.000277  151.666  124.475786  73.695202
# 2024-05-30   43583688     -0.020521  152.713  125.149907  74.086336
# 2024-05-31   56435354      0.006795  153.464  125.813233  74.483042
# 2024-06-03  112293004      0.062711  154.504  126.561773  74.912042
#
#                  20_MA  Upper_Band  Lower_Band        RSI
# Date
# ...

# %%
plt.plot(irfc_stock["RSI"])
plt.title("IRFC stock Relative Strength Index(RSI)")
plt.xlabel("Date")
plt.ylabel("RSI")
plt.show()

# %%
delta_hal = hal_stock["Adj Close"].diff(1)
gain_hal = (delta_hal.where(delta_hal>0,0)).rolling(window =14).mean()
loss_hal = (-delta_hal.where(delta_hal<0,0)).rolling(window =14).mean()
rs_hal = gain_hal/ loss_hal
hal_stock["RSI"] = 100 -(100/(1+rs_hal))

# %%
plt.plot(hal_stock["RSI"])
plt.title("HAL stock Relative Strength Index(RSI)")
plt.xlabel("Date")
plt.ylabel("RSI")
plt.show()

# %%
delta_bdl = bdl_stock["Adj Close"].diff(1)
gain_bdl = (delta_bdl.where(delta_bdl>0,0)).rolling(window =14).mean()
loss_bdl = (-delta_bdl.where(delta_bdl<0,0)).rolling(window =14).mean()
rs_bdl = gain_bdl/ loss_bdl
bdl_stock["RSI"] = 100 -(100/(1+rs_bdl))

# %%
plt.plot(bdl_stock["RSI"])
plt.title("BDL stock Relative Strength Index(RSI)")
plt.xlabel("Date")
plt.ylabel("RSI")
plt.show()
